# %%
import matplotlib.pyplot as plt

# %%
savings = [0,100,150,200,250]
months = ['Jan','Feb','Mar','Apr','May']

# %%
plt.plot(months, savings)
plt.xlabel('Month')
plt.ylabel('Savings ($)')
plt.title('Savings Account Results')
plt.show()
